# %%
import matplotlib.pyplot as plt
import numpy as np
from utils.units import *

# %% [markdown]
# ## L852SEV1 VHG diode laser

# %%
I_mA = np.array([10, 20, 30, 40, 45, 48, 50, 52, 54, 60, 70, 80, 90, 100])

P_mW = np.array([6.5*uW, 16.56*uW, 37.2*uW, 118.9*uW, 264*uW, 0.441*mW, 0.65*mW, 0.996*mW, 2.6*mW, 12.7*mW, 29*mW, 45.4*mW, 62.1*mW, 78.8*mW])/mW

plt.plot(I_mA, P_mW, label="measured")
plt.scatter(I_mA, P_mW, marker='x')
plt.title("L852SEV1 laser, 2025.04.02")
plt.axvline(54.4, c='grey',ls='--', label='Thorlabs test I_th')
plt.xlabel("laser current (mA)")
plt.ylabel("laser power (mW)")
plt.legend()

# %% [markdown]
# ## DBR852PN butterfly laser

# %%
I_mA = np.array([5,10,15,20,25,30,35,40, 45, 50, 51, 52, 55, 60, 70, 80, 90, 100, 110, 125, 150, 175]) 
P_mW = np.array([0.012*uW,0.043*uW,0.098*uW, 0.185*uW, 0.323*uW, 0.541*uW, 0.883*uW, 1.42*uW, 2.25*uW, 4.47*uW, 0.125*mW, 0.258*mW, 0.55*mW, 
     0.971*mW, 1.8*mW, 2.64*mW, 3.49*mW, 4.36*mW, 5.25*mW, 6.61*mW, 8.96*mW, 11.4*mW])/mW

plt.plot(I_mA, P_mW, label="measured")
plt.title("DBR852PN laser, 2025.03.06")
plt.axvline(53.8, c='grey',ls='--', label='Thorlabs test I_th')
plt.xlabel("laser current (mA)")
plt.ylabel("laser power (mW)")
plt.legend()
